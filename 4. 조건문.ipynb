# %% [markdown]
# # 조건문(if 문)

# %%
today_temp = 32

if today_temp >0:
    print("아이스 아메리카노")
# Out:
# 아이스 아메리카노

# %%
today_temp = float(input("온도 입력"))

if today_temp >0:
    print("아이스 아메리카노")

# %%
today_temp = float(input("온도 입력"))

if today_temp >0:
    print("아이스 아메리카노")
else:
    print("따뜻한 아메리카노")
# Out:
# 아이스 아메리카노

# %%
today_temp = float(input("온도 입력"))

if today_temp >0:
    print("아이스 아메리카노")
elif today_temp==0:
    print("미지근한 아메리카노")
else:
    print("따뜻한 아메리카노")
# Out:
# 미지근한 아메리카노

# %%
id = input("아이디를 입력하세요")
password = input("비밀번호를 입력하세요")

admin_id="abcd"
admin_pw="1234"

if (id ==admin_id )&(password == admin_pw):
    print("로그인 성공")
else:
    print("로그인 실패")
# Out:
# 로그인 실패

# %%
today_temp = float(input("온도 입력"))
weather = "맑음"

if weather == "맑음":
    if today_temp >0:
        print("아이스 아메리카노")
    elif today_temp==0:
        print("미지근한 아메리카노")
    else:
        print("따뜻한 아메리카노")
else:
    print("카푸치노")
# Out:
# 아이스 아메리카노

# %%
num =float(input("숫자 입력"))

if num>0:
    print("양수 입니다.")
elif num==0:
    print("0 입니다.")
else:
    print("음수 입니다.")
# Out:
# 양수 입니다.

# %%
6//2
# Out:
# 3

# %%
6/2
# Out:
# 3.0

# %%
6%2
# Out:
# 0
