# %% [markdown]
# Physical AI
#
# why python?
#
# data handling, all library import easily
#
# 다른 언어들과 조합하여 사용하기 좋음

# %% [markdown]
# # 리스트

# %%
score_1=80
score_2=90
score_3=100
score_4=70
score_5=60
score_6=50
score_7=80
score_8=90
score_9=100
score_10=70

# %%
score_list=[80,90,100,70,60,50,80,90,100,70]
score_list
# Out:
# [80, 90, 100, 70, 60, 50, 80, 90, 100, 70]

# %% [markdown]
# 1. 리스트(list) : []

# %%
fruit_list=['apple', 'banana', 'orange']
fruit_list
# Out:
# ['apple', 'banana', 'orange']

# %%
#list 자료형은 원소 중복 허용
fruit_list=['apple', 'banana', 'orange','apple', 'banana']
fruit_list
# Out:
# ['apple', 'banana', 'orange', 'apple', 'banana']

# %%
fruit_list[0]
# Out:
# 'apple'

# %%
fruit_list[1]
# Out:
# 'banana'

# %%
fruit_list[-3]
# Out:
# 'orange'

# %%
len(fruit_list)
# Out:
# 5

# %%
fruit_list[0:3]
# Out:
# ['apple', 'banana', 'orange']

# %%
fruit_list[-5:-2]
# Out:
# ['apple', 'banana', 'orange']

# %%
fruit_list
# Out:
# ['apple', 'banana', 'orange', 'apple', 'banana']

# %%
fruit_list[1] = 'kiwi'
fruit_list
# Out:
# ['apple', 'kiwi', 'orange', 'apple', 'banana']

# %%
#kiwi -> strawberry, orange -> grape

fruit_list[1:3]=['strawberry', 'blueberry']

# %%
fruit_list
# Out:
# ['apple', 'strawberry', 'blueberry', 'apple', 'banana']

# %%
fruit_list.insert(2,'mango')

# %%
fruit_list
# Out:
# ['apple', 'strawberry', 'mango', 'blueberry', 'apple', 'banana']

# %%
fruit_list.insert(4,'orange')

# %%
fruit_list.insert(8, 'watermelon')

# %%
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon']

# %% [markdown]
# appendix : 부록
# append : 끝에 붙이다.

# %%
fruit_list.append('melon')

# %%
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon']

# %%
vegetable_list=['carrot', 'onion', 'tomato']
vegetable_list
# Out:
# ['carrot', 'onion', 'tomato']

# %%
fruit_list.extend(vegetable_list)

# %%
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon',
#  'carrot',
#  'onion',
#  'tomato']

# %%
fruit_list.remove('carrot')
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon',
#  'onion',
#  'tomato']

# %%
# remove : 함수 del : 명령어(revoke 안됨)
del fruit_list[-1]
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon']

# %%
fruit_list.clear()
fruit_list
# Out:
# []

# %%
fruit_list=['apple', 'banana', 'orange','apple', 'banana']
fruit_list
# Out:
# ['apple', 'banana', 'orange', 'apple', 'banana']

# %%
fruit_list.sort() #오름차순

# %%
fruit_list
# Out:
# ['apple', 'apple', 'banana', 'banana', 'orange']

# %%
fruit_list.sort(reverse=True) #내림차순

# %%
fruit_list
# Out:
# ['orange', 'banana', 'banana', 'apple', 'apple']

# %% [markdown]
# # 튜플:  ()

# %%
fruit_list = ('apple', 'bannana', 'orange')
fruit_list[1]
# Out:
# 'bannana'

# %% [markdown]
# fruit_list[1]='kiwi'
#
# 튜플은 아이템 변경이 불가능
#
# 리스트는 아이템 변경이 가능

# %% [markdown]
# fruit_list.append('watermelon')
#
# 튜플에는 append, insert, remove, clear, sort, reverse 등의 메서드가 없음
#
# 그래서 잘 사용안함
#
# 튜플 -> 리스트

# %%
fruit_list = list(fruit_list)
fruit_list
# Out:
# ['apple', 'bannana', 'orange']

# %%
fruit_list.append('watermelon')

# %%
fruit_list
# Out:
# ['apple', 'bannana', 'orange', 'watermelon']

# %%
fruit_list=tuple(fruit_list)

# %%
fruit_list
# Out:
# ('apple', 'bannana', 'orange', 'watermelon')

# %% [markdown]
# # set,세트 : {}

# %%
fruit_list = {'apple', 'banana', 'orange'}
fruit_list
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruit_list = {'apple', 'banana', 'apple', 'orange'}
fruit_list
#원소의 중복을 허용하지 않음 단 오류를 발생시키지 않음 > 단일 원소값으로 인식
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruit_list.add("kiwi")
fruit_list
#자동으로 오름차순으로 정렬됨
# Out:
# {'apple', 'banana', 'kiwi', 'orange'}

# %%
vegetable_list = {'carrot', 'tomato', 'onion'}
vegetable_list
# Out:
# {'carrot', 'onion', 'tomato'}

# %%
fruit_list.update(vegetable_list)

# %%
fruit_list
# Out:
# {'apple', 'banana', 'carrot', 'kiwi', 'onion', 'orange', 'tomato'}

# %%
fruit_list.remove('onion')
fruit_list
# Out:
# {'apple', 'banana', 'carrot', 'kiwi', 'orange', 'tomato'}

# %%
fruit_list.clear()
fruit_list
# Out:
# set()

# %% [markdown]
# # 딕셔너리(dictionary) : {key : value}

# %%
my_dict = {
    "name" : "홍길동",
    "age" : 25,
    "height" : 180,
    "weight" : 70
}

# %%
my_dict
# Out:
# {'name': '홍길동', 'age': 25, 'height': 180, 'weight': 70}

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age', 'height', 'weight'])

# %%
my_dict.values()
# Out:
# dict_values(['홍길동', 25, 180, 70])

# %%
my_dict['age']
# Out:
# 25

# %%
my_dict['height']
# Out:
# 180

# %%
my_dict['height'] = 175

# %%
my_dict['height']
# Out:
# 175

# %%
my_dict['age']=21
my_dict
# Out:
# {'name': '홍길동', 'age': 21, 'height': 175, 'weight': 70}

# %%
my_dict.update(
    {
        '주소' : '충남 당진시',
        '취미' : '게임',
        '음식' : '치킨'
    }
)

# %%
my_dict
# Out:
# {'name': '홍길동',
#  'age': 21,
#  'height': 175,
#  'weight': 70,
#  '주소': '충남 당진시',
#  '취미': '게임',
#  '음식': '치킨'}

# %%
my_dict.pop('음식')
# Out:
# '치킨'

# %%
my_dict
# Out:
# {'name': '홍길동',
#  'age': 21,
#  'height': 175,
#  'weight': 70,
#  '주소': '충남 당진시',
#  '취미': '게임'}

# %%
my_dict.popitem()
# Out:
# ('취미', '게임')

# %%
my_dict
# Out:
# {'name': '홍길동', 'age': 21, 'height': 175, 'weight': 70, '주소': '충남 당진시'}
