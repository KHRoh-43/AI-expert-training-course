# %%
a=5
a
# Out:
# 5

# %%
a=7
a
# Out:
# 7

# %%
b=6
a+b
# Out:
# 13

# %%
c="ArithmeticError"
c='ArithmeticError'

# %% [markdown]
# 셀의 실행
#
# python -> Markdown m
#
# markdown -> python y
#
# 셀 아래 셀 b
#
# 셀 위에 셀 a
#
# 셀 삭제 dd
#
# 여러 셀 삭제 shift+dd
#
# 현재 셀 실행 후 다음 셀로 이동 shift+enter
#
# 현재 셀 실행 ctrl+enter

# %% [markdown]
# ## 2.변수규칙

# %%
#변수 이름에 숫자가 들어갈 수 있지만, 숫자로 시작할 수는 없다.
#변수 이름에 공백을 넣을 수 없다.
#변수 이름에 특수문자를 넣을 수 없다. 단, _는 허용된다.

# %%
x,y,z = 1,2,3
x
y
z
# Out:
# 3

# %%
x=y=z="apple"
x
# Out:
# 'apple'

# %%
y
# Out:
# 'apple'

# %%
z
# Out:
# 'apple'

# %% [markdown]
# # 3.데이터 타입

# %% [markdown]
# 1) 숫자형  : 정수형(integer), 실수형(float)

# %%
x,y,z=10,3.15,-35

# %%
type(y)
# Out:
# float

# %% [markdown]
# e3 : 10의 3제곱

# %%
a =17e3
a
# Out:
# 17000.0

# %%
#e-3 : 10의 13제곱을 의미
b = 17e-3
b
# Out:
# 0.017

# %% [markdown]
# # 4.boolean

# %%
b = 100>50
b
# Out:
# True

# %%
c=100==50
c
# Out:
# False

# %% [markdown]
# # 5. 문자형

# %%
a="hello"
type(a)
# Out:
# str

# %%
b='123'
type(b)
# Out:
# str

# %%
temperature = "30"
huminity = "80"

# %%
temperature + huminity
# Out:
# '3080'

# %%
#형변환
int(temperature) + int(huminity)
# Out:
# 110

# %%
a =0 
b = 500
c = "" #공백도 값이 있는것
d = "울랄라"

# %%
type(a)
# Out:
# int

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# str

# %%
bool(a)
# Out:
# False

# %%
bool(b)
# Out:
# True

# %%
bool(c)
# Out:
# False

# %%
bool(d)
# Out:
# True
